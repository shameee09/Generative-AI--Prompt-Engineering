# %%
# !pip install gradio
# Out:
# Collecting gradio
#   Downloading gradio-6.28.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in d:\users\admin\anaconda3\lib\site-packages (from gradio) (4.10.0)
# Collecting audioop-lts<=0.2.2 (from gradio)
#   Downloading audioop_lts-0.2.2-cp313-abi3-win_amd64.whl.metadata (2.0 kB)
# Collecting brotli>=1.1.0 (from gradio)
#   Downloading brotli-1.2.0-cp313-cp313-win_amd64.whl.metadata (6.3 kB)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.141.1-py3-none-any.whl.metadata (27 kB)
# Collecting gradio-client==2.7.1 (from gradio)
#   Downloading gradio_client-2.7.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio)
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting hf-gradio<1.0,>=0.4.1 (from gradio)
#   Downloading hf_gradio-0.4.1-py3-none-any.whl.metadata (428 bytes)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in d:\users\admin\anaconda3\lib\site-packages (from gradio) (0.28.1)
# Collecting huggingface-hub<2.0,>=1.16.0 (from gradio)
#   Downloading huggingface_hub-1.32.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: jinja2<4.0 in d:\users\admin\anaconda3\lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in d:\users\admin\anaconda3\lib\site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in d:\users\admin\anaconda3\lib\site-packages (from gradio) (2.3.5)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.12.0-cp313-cp313-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: packaging in d:\users\admin\anaconda3\lib\site-packages (from gradio) (25.0)
# Requirement already satisfied: pandas<4.0,>=1.0 in d:\users\admin\anaconda3\lib\site-packages (from gradio) (2.3.3)
# Requirement already satisfied: pillow<13.0,>=8.0 in d:\users\admin\anaconda3\lib\site-packages (from gradio) (12.0.0)
# Requirement already satisfied: pydantic<=3.0,>=2.0 in d:\users\admin\anaconda3\lib\site-packages (from gradio) (2.13.5)
# Collecting pydub<1.0 (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart<1.0,>=0.0.18 (from gradio)
#   Downloading python_multipart-0.0.32-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: pytz>=2017.2 in d:\users\admin\anaconda3\lib\site-packages (from gradio) (2025.2)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in d:\users\admin\anaconda3\lib\site-packages (from gradio) (6.0.3)
# Collecting safehttpx<0.2.0,>=0.1.7 (from gradio)
#   Downloading safehttpx-0.1.7-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<2.0,>=1.0.1 (from gradio)
#   Downloading starlette-1.7.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: tomlkit<0.15.0,>=0.12.0 in d:\users\admin\anaconda3\lib\site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in d:\users\admin\anaconda3\lib\site-packages (from gradio) (0.20.0)
# Requirement already satisfied: typing-extensions~=4.0 in d:\users\admin\anaconda3\lib\site-packages (from gradio) (4.15.0)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.53.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: fsspec in d:\users\admin\anaconda3\lib\site-packages (from gradio-client==2.7.1->gradio) (2025.10.0)
# Requirement already satisfied: idna>=2.8 in d:\users\admin\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.20)
# Requirement already satisfied: sniffio>=1.1 in d:\users\admin\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\users\admin\anaconda3\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.4.2)
# Collecting annotated-doc>=0.0.2 (from fastapi<1.0,>=0.115.2->gradio)
#   Downloading annotated_doc-0.0.5-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: certifi in d:\users\admin\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in d:\users\admin\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\users\admin\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Collecting click<9.0.0,>=8.4.2 (from huggingface-hub<2.0,>=1.16.0->gradio)
#   Downloading click-8.5.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: filelock>=3.10.0 in d:\users\admin\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.16.0->gradio) (3.20.0)
# Collecting hf-xet<2.0.0,>=1.5.2 (from huggingface-hub<2.0,>=1.16.0->gradio)
#   Downloading hf_xet-1.6.0-cp38-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: tqdm>=4.42.1 in d:\users\admin\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.16.0->gradio) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\users\admin\anaconda3\lib\site-packages (from pandas<4.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in d:\users\admin\anaconda3\lib\site-packages (from pandas<4.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\users\admin\anaconda3\lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.5 in d:\users\admin\anaconda3\lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (2.46.5)
# Requirement already satisfied: shellingham>=1.3.0 in d:\users\admin\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in d:\users\admin\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (14.2.0)
# Requirement already satisfied: six>=1.5 in d:\users\admin\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\users\admin\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\users\admin\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in d:\users\admin\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Requirement already satisfied: colorama in d:\users\admin\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<2.0,>=1.16.0->gradio) (0.4.6)
# Downloading gradio-6.28.0-py3-none-any.whl (31.4 MB)
#    ---------------------------------------- 0.0/31.4 MB ? eta -:--:--
#     --------------------------------------- 0.5/31.4 MB 3.0 MB/s eta 0:00:11
#    -- ------------------------------------- 1.6/31.4 MB 4.2 MB/s eta 0:00:08
#    --- ------------------------------------ 2.9/31.4 MB 4.7 MB/s eta 0:00:07
#    ----- ---------------------------------- 3.9/31.4 MB 4.9 MB/s eta 0:00:06
#    ------ --------------------------------- 5.0/31.4 MB 5.1 MB/s eta 0:00:06
#    ------- -------------------------------- 6.0/31.4 MB 5.0 MB/s eta 0:00:06
#    --------- ------------------------------ 7.3/31.4 MB 5.0 MB/s eta 0:00:05
#    ---------- ----------------------------- 8.1/31.4 MB 5.0 MB/s eta 0:00:05
#    ----------- ---------------------------- 9.2/31.4 MB 5.0 MB/s eta 0:00:05
#    ------------- -------------------------- 10.5/31.4 MB 5.0 MB/s eta 0:00:05
#    -------------- ------------------------- 11.5/31.4 MB 5.0 MB/s eta 0:00:04
#    ---------------- ----------------------- 12.6/31.4 MB 5.0 MB/s eta 0:00:04
#    ----------------- ---------------------- 13.6/31.4 MB 5.0 MB/s eta 0:00:04
#    ------------------ --------------------- 14.7/31.4 MB 5.1 MB/s eta 0:00:04
#    -------------------- ------------------- 15.7/31.4 MB 5.1 MB/s eta 0:00:04
#    --------------------- ------------------ 17.0/31.4 MB 5.1 MB/s eta 0:00:03
#    ----------------------- ---------------- 18.1/31.4 MB 5.1 MB/s eta 0:00:03
#    ------------------------ --------------- 19.4/31.4 MB 5.2 MB/s eta 0:00:03
#    -------------------------- ------------- 20.4/31.4 MB 5.1 MB/s eta 0:00:03
#    --------------------------- ------------ 21.5/31.4 MB 5.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 22.5/31.4 MB 5.2 MB/s eta 0:00:02
#    ------------------------------ --------- 23.6/31.4 MB 5.1 MB/s eta 0:00:02
#    ------------------------------- -------- 24.9/31.4 MB 5.1 MB/s eta 0:00:02
#    --------------------------------- ------ 26.0/31.4 MB 5.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 27.0/31.4 MB 5.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 27.8/31.4 MB 5.1 MB/s eta 0:00:01
#    ------------------------------------- -- 29.1/31.4 MB 5.1 MB/s eta 0:00:01
#    -------------------------------------- - 30.1/31.4 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------  31.2/31.4 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 31.4/31.4 MB 5.0 MB/s  0:00:06
# Downloading gradio_client-2.7.1-py3-none-any.whl (63 kB)
# Downloading audioop_lts-0.2.2-cp313-abi3-win_amd64.whl (30 kB)
# Downloading fastapi-0.141.1-py3-none-any.whl (131 kB)
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading hf_gradio-0.4.1-py3-none-any.whl (4.5 kB)
# Downloading huggingface_hub-1.32.0-py3-none-any.whl (842 kB)
#    ---------------------------------------- 0.0/842.9 kB ? eta -:--:--
#    ---------------------------------------- 842.9/842.9 kB 3.9 MB/s  0:00:00
# Downloading click-8.5.0-py3-none-any.whl (125 kB)
# Downloading hf_xet-1.6.0-cp38-abi3-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------- ----------------------------- 1.0/4.0 MB 6.2 MB/s eta 0:00:01
#    -------------------- ------------------- 2.1/4.0 MB 5.3 MB/s eta 0:00:01
#    ------------------------------- -------- 3.1/4.0 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 5.1 MB/s  0:00:00
# Downloading orjson-3.12.0-cp313-cp313-win_amd64.whl (121 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading python_multipart-0.0.32-py3-none-any.whl (30 kB)
# Downloading safehttpx-0.1.7-py3-none-any.whl (9.0 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-1.7.0-py3-none-any.whl (78 kB)
# Downloading annotated_doc-0.0.5-py3-none-any.whl (5.3 kB)
# Downloading brotli-1.2.0-cp313-cp313-win_amd64.whl (369 kB)
# Downloading uvicorn-0.53.0-py3-none-any.whl (87 kB)
# Installing collected packages: pydub, brotli, semantic-version, python-multipart, orjson, hf-xet, groovy, click, audioop-lts, annotated-doc, uvicorn, starlette, safehttpx, huggingface-hub, fastapi, gradio-client, hf-gradio, gradio
#
#    -- -------------------------------------  1/18 [brotli]
#    ------ ---------------------------------  3/18 [python-multipart]
#    ----------- ----------------------------  5/18 [hf-xet]
#    ------------- --------------------------  6/18 [groovy]
#   Attempting uninstall: click
#    ------------- --------------------------  6/18 [groovy]
#     Found existing installation: click 8.2.1
#    ------------- --------------------------  6/18 [groovy]
#     Uninstalling click-8.2.1:
#    ------------- --------------------------  6/18 [groovy]
#       Successfully uninstalled click-8.2.1
#    ------------- --------------------------  6/18 [groovy]
#    --------------- ------------------------  7/18 [click]
#    --------------- ------------------------  7/18 [click]
#    --------------- ------------------------  7/18 [click]
#    ---------------------- ----------------- 10/18 [uvicorn]
#    ---------------------- ----------------- 10/18 [uvicorn]
#    ---------------------- ----------------- 10/18 [uvicorn]
#    ------------------------ --------------- 11/18 [starlette]
#    ------------------------ --------------- 11/18 [starlette]
#    ------------------------ --------------- 11/18 [starlette]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ---------------------------- ----------- 13/18 [huggingface-hub]
#    ------------------------------- -------- 14/18 [fastapi]
#    ------------------------------- -------- 14/18 [fastapi]
#    ------------------------------- -------- 14/18 [fastapi]
#    ------------------------------- -------- 14/18 [fastapi]
#    --------------------------------- ------ 15/18 [gradio-client]
#    ----------------------------------- ---- 16/18 [hf-gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ------------------------------------- -- 17/18 [gradio]
#    ---------------------------------------- 18/18 [gradio]
#
# Successfully installed annotated-doc-0.0.5 audioop-lts-0.2.2 brotli-1.2.0 click-8.5.0 fastapi-0.141.1 gradio-6.28.0 gradio-client-2.7.1 groovy-0.1.2 hf-gradio-0.4.1 hf-xet-1.6.0 huggingface-hub-1.32.0 orjson-3.12.0 pydub-0.25.1 python-multipart-0.0.32 safehttpx-0.1.7 semantic-version-2.10.0 starlette-1.7.0 uvicorn-0.53.0

# %%
import os
import gradio as gr
from dotenv import load_dotenv
from google import genai
from google.genai import types

load_dotenv(".env", override=True)

client = genai.Client(
    api_key=os.getenv("GEMINI_API_KEY")
)

MODEL = "gemini-3.5-flash-lite"

system_msg = """
You are a financial expert specializing in real estate investment and negotiation.
Provide clear, practical, and easy-to-understand financial guidance.
"""

chat = client.chats.create(
    model=MODEL,
    config=types.GenerateContentConfig(
        system_instruction=system_msg
    )
)


def CustomGemini(user_input):
    
    response = chat.send_message(user_input)

    return response.text

demo = gr.Interface(
    fn=CustomGemini,
    inputs="text",
    outputs="text",
    title="My Saving Assistant"
)
demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
#
# Could not create share link. Please check your internet connection or our status page: https://status.gradio.app.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
