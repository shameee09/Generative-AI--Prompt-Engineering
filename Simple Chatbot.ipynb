# %%
import os
from dotenv import load_dotenv
from google import genai

load_dotenv(".env", override=True)

client = genai.Client(
    api_key=os.getenv("GEMINI_API_KEY")
)

MODEL = "gemini-3.5-flash-lite"

prompt = "Give me 3 ideas for apps I could build with Gemini APIs."

response = client.models.generate_content(
    model=MODEL,
    contents=prompt
)

print(response.text)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# Here are three distinct app ideas that leverage the power of the Gemini APIs, ranging from everyday utility to niche creativity. Each idea takes advantage of Gemini's multimodal capabilities (text, code, vision, and audio).
#
# ---
#
# ### 1. "PantryChef AI" (Multimodal Recipe & Waste Reducer)
# * **The Concept:** A mobile app designed to help users reduce food waste and save money on groceries.
# * **How it uses Gemini API:**
#     * **Vision:** The user opens the app and takes a photo of the contents of their fridge or pantry (no need to manually type ingredients). Gemini’s multimodal vision capabilities analyze the image and identify the ingredients.
#     * **Text/Reasoning:** The app sends the detected ingredients to Gemini with a prompt like: *"Create three distinct recipes using these ingredients, plus basic pantry staples like oil, salt, and flour. Categorize them by cooking time."*
#     * **Audio (Optional):** Users can use Gemini's audio capabilities for hands-free step-by-step cooking instructions while their hands are messy.
# * **Why it’s great:** It solves a universal, everyday problem (the "what's for dinner with nothing in the fridge" dilemma) and showcases Gemini's superior image recognition.
#
# ---
#
# ### 2. "LegacyLoom" (Interactive Family History & Memoir Generator)
# * **The Concept:** An app that helps older generations preserve their life stories by turning casual voice conversations into beautifully written, structured autobiographies.
# * **How it uses Gemini API:**
#     * **Audio & Long Context:** Grandparents (or users) record rambling voice notes answering prompts like "Tell me about your first car" or "How did you meet grandma?" Thanks to Gemini's massive context window, hours of audio can be uploaded at once.
#     * **Text Generation:** Gemini transcribes, cleans up filler words, and translates the oral history into a polished narrative written in the storyteller's unique voice.
#     * **Image Generation Integration:** Gemini can also analyze the text to suggest prompts for historical photo matching or AI image generation to illustrate the chapters (e.g., *"Generate a 1950s diner scene based on this memory"*).
# * **Why it’s great:** It taps into the emotional, sentimental market. It uses Gemini's huge context window to handle massive amounts of audio/text data without losing the plot.
#
# ---
#
# ### 3. "CodeDebug VR / AR" (Visual Code Explainer for Beginners)
# * **The Concept:** A developer-focused tool (built as a web or mobile app) that helps beginner programmers understand cryptic error messages or complex code snippets simply by looking at them.
# * **How it uses Gemini API:**
#     * **Vision:** The user takes a screenshot of their IDE showing a bug, a stack trace, or a confusing piece of legacy code.
#     * **Code & Reasoning:** Gemini analyzes the code context, identifies the logical error or the cause of the stack trace, and provides a breakdown.
#     * **Interactive Socratic Teaching:** Instead of just giving the answer, Gemini is prompted to act as a mentor, asking guiding questions to help the junior developer learn *why* the error happened and how to fix it themselves.
# * **Why it’s great:** Coding education is a massive market. This goes beyond standard chatbots by integrating directly with screenshots of errors, which is how developers actually encounter problems.
#
# ---
#
# ### Pro-Tip for Building:
# If you build any of these, make sure to leverage **Structured Outputs (JSON mode)** in the Gemini API. This ensures that the AI returns data in a predictable format that your app's frontend can easily render (e.g., parsing the ingredients list or recipe steps into UI cards).
